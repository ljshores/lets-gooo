# %%
import numpy as np
import pandas as pd
#import re

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Project Overview 📝
#
# - **Project Title**:
# - **Goal of the project**:
# - **Dataset(s) used**:
# - **Team Members**:
#
# ## 2. Data Overview 📁
#
# - **Source(s) of the Data**:
# - **Data Size**:
# - **Brief Description of the Data**:
#
# ## 3. Data Cleaning and Preparation 🔧
#
# - **Missing Value Treatment**:
# - **Outlier Detection & Treatment**:
# - **Feature Engineering**:

# %%
df = pd.read_csv("/content/WineQT.csv")
print(df.head())

# %% [markdown]
# # Take Stock of the Data
# https://www.geeksforgeeks.org/data-analysis/exploratory-data-analysis-in-python/

# %%
df.shape

# %%
df.info()

# %%
df.describe().T

# %%
df.columns.tolist()

# %%
# check missing values
df.isnull().sum()

# %%
# check for duplicates
df.nunique()

# %%
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns

# %% [markdown]
# # Univariate

# %%
var # = categorical variable to observe
vc = df[var].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, vc, color='deeppink')
plt.title('Count Plot')
#plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %%
sns.set_style("darkgrid")


plt.figure(figsize=(14, len(numerical_columns) * 3))
for idx, feature in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 2, idx)
    sns.histplot(df[feature], kde=True)
    plt.title(f"{feature} | Skewness: {round(df[feature].skew(), 2)}")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bivariate

# %%
# pair plot
sns.set_palette("Pastel1")

plt.figure(figsize=(10, 6))

sns.pairplot(df)

plt.suptitle('Pair Plot for DataFrame')
plt.show()

# %%
# box plot for observing cat on x axis and distribution for numerical var on y axis

sns.boxplot(x='quality', y='alcohol', data=df)

# %%
# correlation matrix

plt.figure(figsize=(15, 10))

sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='Pastel2', linewidths=2)

plt.title('Correlation Heatmap')
plt.show()
